# %% [markdown]
# <a href="https://colab.research.google.com/github/H0N3YBEE/H0N3YBEE/blob/main/Jamaila.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("jamaila")
# Out:
# jamaila

# %%
list_1 = [1,2,3,4]

# %%
print(list_1)
# Out:
# [1, 2, 3, 4]

# %%
len(list_1)
# Out:
# 4

# %%
for i in range(len(list_1)):
  print(i*2)
# Out:
# 0
# 2
# 4
# 6

# %%
import numpy as np

# %%
arr=np.array(list_1)
print(arr)
for i in arr:
  print(i*2)
type(arr)
# Out:
# [1 2 3 4]
# 2
# 4
# 6
# 8
# numpy.ndarray

# %%
large_list = list(range(1,10000))
len(large_list)
# Out:
# 9999

# %%
# %%timeit
for i in large_list:
  i*2
# Out:
# 516 µs ± 108 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
import pandas as pd

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O data.csv
# Out:
# --2023-08-31 16:07:49--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 64.233.189.113, 64.233.189.138, 64.233.189.100, ...
# Connecting to drive.google.com (drive.google.com)|64.233.189.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/q4oi68gu4s6gtbmsf34fhq1a1eon09sp/1693498050000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=0c047b90-ce7d-4be9-8a12-db3b518cf063 [following]
# Warning: wildcards not supported in HTTP.
# --2023-08-31 16:07:50--  https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/q4oi68gu4s6gtbmsf34fhq1a1eon09sp/1693498050000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=0c047b90-ce7d-4be9-8a12-db3b518cf063
# Resolving doc-0s-68-docs.googleusercontent.com (doc-0s-68-docs.googleusercontent.com)... 108.177.97.132, 2404:6800:4008:c00::84
# Connecting to doc-0s-68-docs.googleusercontent.com (doc-0s-68-docs.googleusercontent.com)|108.177.97.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [text/csv]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>]  81.82K  --.-KB/s    in 0.001s
#
# 2023-08-31 16:07:50 (91.8 MB/s) - ‘data.csv’ saved [83785/83785]

# %%
df = pd.read_csv("data.csv")

# %%
df.head(20)
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# 13      Albania  1957     1476505    Europe    59.280  1942.284244
# 14      Albania  1962     1728137    Europe    64.820  2312.888958
# 15      Albania  1967     1984060    Europe    66.220  2760.196931
# 16      Albania  1972     2263554    Europe    67.690  3313.422188
# 17      Albania  1977     2509048    Europe    68.930  3533.003910
# 18      Albania  1982     2780097    Europe    70.420  3630.880722
# 19      Albania  1987     3075321    Europe    72.000  3738.932735

# %%
df.tail(6)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165876
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846988
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
min_exp = df["life_exp"].min()

# %%
print(min_exp)
# Out:
# 23.599

# %%
df["life_exp"] == min_exp
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: life_exp, Length: 1704, dtype: bool

# %%
true_false_val = df["life_exp"] == min_exp

# %%
df[true_false_val]
# Out:
#      country  year  population continent  life_exp     gdp_cap
# 1292  Rwanda  1992     7290203    Africa    23.599  737.068595

# %%
max_exp = df["life_exp"].max()

# %%
df[df["life_exp"] == max_exp]
# Out:
#     country  year  population continent  life_exp      gdp_cap
# 803   Japan  2007   127467972      Asia    82.603  31656.06806

# %%
df_Ind = df[df["country"] == 'India']

# %%
df_Ind
# Out:
#     country  year  population continent  life_exp      gdp_cap
# 696   India  1952   372000000      Asia    37.373   546.565749
# 697   India  1957   409000000      Asia    40.249   590.061996
# 698   India  1962   454000000      Asia    43.605   658.347151
# 699   India  1967   506000000      Asia    47.193   700.770611
# 700   India  1972   567000000      Asia    50.651   724.032527
# 701   India  1977   634000000      Asia    54.208   813.337323
# 702   India  1982   708000000      Asia    56.596   855.723538
# 703   India  1987   788000000      Asia    58.553   976.512676
# 704   India  1992   872000000      Asia    60.223  1164.406809
# 705   India  1997   959000000      Asia    61.765  1458.817442
# 706   India  2002  1034172547      Asia    62.879  1746.769454
# 707   India  2007  1110396331      Asia    64.698  2452.210407

# %%
df_Ind.plot('year','gdp_cap')
# Out:
# <Axes: xlabel='year'>

# %%
df["year"].value_counts()
# Out:
# 1952    142
# 1957    142
# 1962    142
# 1967    142
# 1972    142
# 1977    142
# 1982    142
# 1987    142
# 1992    142
# 1997    142
# 2002    142
# 2007    142
# Name: year, dtype: int64

# %%
df.groupby(by="year")["life_exp"].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: life_exp, dtype: float64

# %%
df.groupby(by="country")["gdp_cap"].max()
# Out:
# country
# Afghanistan             978.011439
# Albania                5937.029526
# Algeria                6223.367465
# Angola                 5522.776375
# Argentina             12779.379640
#                           ...
# Vietnam                2441.576404
# West Bank and Gaza     7110.667619
# Yemen, Rep.            2280.769906
# Zambia                 1777.077318
# Zimbabwe                799.362176
# Name: gdp_cap, Length: 142, dtype: float64
